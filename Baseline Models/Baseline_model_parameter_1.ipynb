# %%
import numpy as np
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
freq_labelled = np.load('labelled.npy',allow_pickle = True,mmap_mode = 'r')
rotation = np.load('param_1.npy',allow_pickle = True)

# %%
freq_labelled = freq_labelled[0:20000]
rotation = rotation[0:20000]

# %%
#linear regression param_1
X_train, X_test, y_train, y_test = train_test_split(freq_labelled, rotation, test_size = 0.2,random_state = 98)

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
print("lr.coef_: {}".format(lr.coef_))
print("lr.intercept_: {}".format(lr.intercept_))
print("Training set score: {:.2f}".format(lr.score(X_train, y_train)))
print("Test set score: {:.2f}".format(lr.score(X_test, y_test)))

# %%
#test_ridge param_1
from sklearn.linear_model import Ridge
ridge = Ridge(alpha = 10).fit(X_train, y_train)
print("Training set score: {:.2f}".format(ridge.score(X_train, y_train)))
print("Test set score: {:.2f}".format(ridge.score(X_test, y_test)))

# %%
#test_ridge hyperparams param_1
from sklearn.linear_model import Ridge
ridge = Ridge(alpha = 50).fit(X_train, y_train)
print("Training set score: {:.2f}".format(ridge.score(X_train, y_train)))
print("Test set score: {:.2f}".format(ridge.score(X_test, y_test)))
# Out:
# Training set score: 0.81
# Test set score: 0.73
